# %%
pip freeze "requirements.txt"
# Out:
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# attrs==21.4.0
# audiomentations==0.24.0
# audioread==2.1.9
# auto-sklearn==0.14.6
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.0
# certifi==2021.10.8
# cffi==1.15.0
# charset-normalizer==2.0.12
# click==8.1.3
# cloudpickle==2.0.0
# ConfigSpace==0.4.14
# cycler==0.11.0
# Cython==0.29.28
# dask==2022.5.0
# debugpy==1.6.0
# decorator==5.1.1
# defusedxml==0.7.1
# distributed==2022.5.0
# distro==1.7.0
# emcee==3.1.1
# entrypoints==0.4
# et-xmlfile==1.1.0
# executing==0.8.3
# fastjsonschema==2.15.3
# fonttools==4.33.3
# fsspec==2022.3.0
# future==0.18.2
# HeapDict==1.0.1
# idna==3.3
# importlib-resources==5.7.1
# ipykernel==6.13.0
# ipython==8.3.0
# ipython-genutils==0.2.0
# jedi==0.18.1
# Jinja2==3.1.2
# joblib==1.1.0
# jsonschema==4.4.0
# jupyter-client==7.3.0
# jupyter-core==4.10.0
# jupyterlab-pygments==0.2.2
# kiwisolver==1.4.2
# liac-arff==2.5.0
# librosa==0.9.1
# llvmlite==0.36.0
# locket==1.0.0
# MarkupSafe==2.1.1
# matplotlib==3.5.2
# matplotlib-inline==0.1.3
# mistune==0.8.4
# msgpack==1.0.3
# nbclient==0.6.2
# nbconvert==6.5.0
# nbformat==5.4.0
# nest-asyncio==1.5.5
# networkx==2.8
# notebook==6.4.11
# numba==0.53.0
# numpy==1.21.0
# openpyxl==3.0.9
# packaging==21.3
# pandas==1.4.2
# pandocfilters==1.5.0
# parso==0.8.3
# partd==1.2.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==9.1.0
# pipelineprofiler==0.1.17
# pooch==1.6.0
# prometheus-client==0.14.1
# prompt-toolkit==3.0.29
# psutil==5.9.0
# ptyprocess==0.7.0
# pure-eval==0.2.2
# pycparser==2.21
# pydub==0.25.1
# Pygments==2.12.0
# pyloudnorm==0.1.0
# pynisher==0.6.4
# pyparsing==3.0.8
# pyrfr==0.8.2
# pyrsistent==0.18.1
# python-dateutil==2.8.2
# pytz==2022.1
# PyWavelets==1.3.0
# PyYAML==6.0
# pyzmq==22.3.0
# requests==2.27.1
# resampy==0.2.2
# scikit-learn==0.24.2
# scipy==1.8.0
# Send2Trash==1.8.0
# six==1.16.0
# smac==1.2
# sortedcontainers==2.4.0
# SoundFile==0.10.3.post1
# soupsieve==2.3.2.post1
# stack-data==0.2.0
# tblib==1.7.0
# terminado==0.13.3
# threadpoolctl==3.1.0
# tinycss2==1.1.1
# toolz==0.11.2
# tornado==6.1
# tqdm==4.64.0
# traitlets==5.1.1
# typing-extensions==4.2.0
# urllib3==1.26.9
# wcwidth==0.2.5
# webencodings==0.5.1
# zict==2.2.0
# zipp==3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import librosa 
import librosa.display
import pandas as pd
import soundfile as sf
import sklearn
import matplotlib.pyplot as plt
from tqdm import tqdm
from audiomentations import *
import warnings
import scipy.signal
from pydub import AudioSegment
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from distutils.dir_util import copy_tree
import os
import shutil
try:
    shutil.rmtree("./1.0.1/training_data_balanced/training_data")
except:
    os.mkdir("./1.0.1/training_data_balanced/training_data")
copy_tree("./1.0.1/training_data","./1.0.1/training_data_balanced/training_data")
# Out:
# ['./1.0.1/training_data_balanced/training_data/13918.txt',
#  './1.0.1/training_data_balanced/training_data/13918_AV.hea',
#  './1.0.1/training_data_balanced/training_data/13918_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/13918_AV.wav',
#  './1.0.1/training_data_balanced/training_data/13918_MV.hea',
#  './1.0.1/training_data_balanced/training_data/13918_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/13918_MV.wav',
#  './1.0.1/training_data_balanced/training_data/13918_PV.hea',
#  './1.0.1/training_data_balanced/training_data/13918_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/13918_PV.wav',
#  './1.0.1/training_data_balanced/training_data/13918_TV.hea',
#  './1.0.1/training_data_balanced/training_data/13918_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/13918_TV.wav',
#  './1.0.1/training_data_balanced/training_data/14241.txt',
#  './1.0.1/training_data_balanced/training_data/14241_AV.hea',
#  './1.0.1/training_data_balanced/training_data/14241_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/14241_AV.wav',
#  './1.0.1/training_data_balanced/training_data/14241_MV.hea',
#  './1.0.1/training_data_balanced/training_data/14241_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/14241_MV.wav',
#  './1.0.1/training_data_balanced/training_data/14241_PV.hea',
#  './1.0.1/training_data_balanced/training_data/14241_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/14241_PV.wav',
#  './1.0.1/training_data_balanced/training_data/14241_TV.hea',
#  './1.0.1/training_data_balanced/training_data/14241_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/14241_TV.wav',
#  './1.0.1/training_data_balanced/training_data/14998.txt',
#  './1.0.1/training_data_balanced/training_data/14998_AV.hea',
#  './1.0.1/training_data_balanced/training_data/14998_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/14998_AV.wav',
#  './1.0.1/training_data_balanced/training_data/14998_MV.hea',
#  './1.0.1/training_data_balanced/training_data/14998_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/14998_MV.wav',
#  './1.0.1/training_data_balanced/training_data/14998_PV.hea',
#  './1.0.1/training_data_balanced/training_data/14998_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/14998_PV.wav',
#  './1.0.1/training_data_balanced/training_data/14998_TV.hea',
#  './1.0.1/training_data_balanced/training_data/14998_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/14998_TV.wav',
#  './1.0.1/training_data_balanced/training_data/23625.txt',
#  './1.0.1/training_data_balanced/training_data/23625_AV.hea',
#  './1.0.1/training_data_balanced/training_data/23625_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/23625_AV.wav',
#  './1.0.1/training_data_balanced/training_data/23625_MV.hea',
#  './1.0.1/training_data_balanced/training_data/23625_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/23625_MV.wav',
#  './1.0.1/training_data_balanced/training_data/23625_PV.hea',
#  './1.0.1/training_data_balanced/training_data/23625_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/23625_PV.wav',
#  './1.0.1/training_data_balanced/training_data/23625_TV.hea',
#  './1.0.1/training_data_balanced/training_data/23625_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/23625_TV.wav',
#  './1.0.1/training_data_balanced/training_data/24160.txt',
#  './1.0.1/training_data_balanced/training_data/24160_AV.hea',
#  './1.0.1/training_data_balanced/training_data/24160_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/24160_AV.wav',
#  './1.0.1/training_data_balanced/training_data/24160_MV.hea',
#  './1.0.1/training_data_balanced/training_data/24160_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/24160_MV.wav',
#  './1.0.1/training_data_balanced/training_data/24160_PV.hea',
#  './1.0.1/training_data_balanced/training_data/24160_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/24160_PV.wav',
#  './1.0.1/training_data_balanced/training_data/24160_TV.hea',
#  './1.0.1/training_data_balanced/training_data/24160_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/24160_TV.wav',
#  './1.0.1/training_data_balanced/training_data/2530.txt',
#  './1.0.1/training_data_balanced/training_data/2530_AV.hea',
#  './1.0.1/training_data_balanced/training_data/2530_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/2530_AV.wav',
#  './1.0.1/training_data_balanced/training_data/2530_MV.hea',
#  './1.0.1/training_data_balanced/training_data/2530_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/2530_MV.wav',
#  './1.0.1/training_data_balanced/training_data/2530_PV.hea',
#  './1.0.1/training_data_balanced/training_data/2530_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/2530_PV.wav',
#  './1.0.1/training_data_balanced/training_data/2530_TV.hea',
#  './1.0.1/training_data_balanced/training_data/2530_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/2530_TV.wav',
#  './1.0.1/training_data_balanced/training_data/29045.txt',
#  './1.0.1/training_data_balanced/training_data/29045_AV.hea',
#  './1.0.1/training_data_balanced/training_data/29045_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/29045_AV.wav',
#  './1.0.1/training_data_balanced/training_data/29045_MV.hea',
#  './1.0.1/training_data_balanced/training_data/29045_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/29045_MV.wav',
#  './1.0.1/training_data_balanced/training_data/29045_PV.hea',
#  './1.0.1/training_data_balanced/training_data/29045_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/29045_PV.wav',
#  './1.0.1/training_data_balanced/training_data/29045_TV.hea',
#  './1.0.1/training_data_balanced/training_data/29045_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/29045_TV.wav',
#  './1.0.1/training_data_balanced/training_data/29378.txt',
#  './1.0.1/training_data_balanced/training_data/29378_AV.hea',
#  './1.0.1/training_data_balanced/training_data/29378_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/29378_AV.wav',
#  './1.0.1/training_data_balanced/training_data/29378_MV.hea',
#  './1.0.1/training_data_balanced/training_data/29378_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/29378_MV.wav',
#  './1.0.1/training_data_balanced/training_data/31737.txt',
#  './1.0.1/training_data_balanced/training_data/31737_AV.hea',
#  './1.0.1/training_data_balanced/training_data/31737_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/31737_AV.wav',
#  './1.0.1/training_data_balanced/training_data/31737_MV.hea',
#  './1.0.1/training_data_balanced/training_data/31737_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/31737_MV.wav',
#  './1.0.1/training_data_balanced/training_data/31737_PV.hea',
#  './1.0.1/training_data_balanced/training_data/31737_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/31737_PV.wav',
#  './1.0.1/training_data_balanced/training_data/31737_TV.hea',
#  './1.0.1/training_data_balanced/training_data/31737_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/31737_TV.wav',
#  './1.0.1/training_data_balanced/training_data/33151.txt',
#  './1.0.1/training_data_balanced/training_data/33151_AV.hea',
#  './1.0.1/training_data_balanced/training_data/33151_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/33151_AV.wav',
#  './1.0.1/training_data_balanced/training_data/33151_MV.hea',
#  './1.0.1/training_data_balanced/training_data/33151_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/33151_MV.wav',
#  './1.0.1/training_data_balanced/training_data/33151_PV.hea',
#  './1.0.1/training_data_balanced/training_data/33151_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/33151_PV.wav',
#  './1.0.1/training_data_balanced/training_data/33151_TV.hea',
#  './1.0.1/training_data_balanced/training_data/33151_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/33151_TV.wav',
#  './1.0.1/training_data_balanced/training_data/36327.txt',
#  './1.0.1/training_data_balanced/training_data/36327_AV.hea',
#  './1.0.1/training_data_balanced/training_data/36327_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/36327_AV.wav',
#  './1.0.1/training_data_balanced/training_data/36327_MV.hea',
#  './1.0.1/training_data_balanced/training_data/36327_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/36327_MV.wav',
#  './1.0.1/training_data_balanced/training_data/36327_PV.hea',
#  './1.0.1/training_data_balanced/training_data/36327_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/36327_PV.wav',
#  './1.0.1/training_data_balanced/training_data/36327_TV.hea',
#  './1.0.1/training_data_balanced/training_data/36327_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/36327_TV.wav',
#  './1.0.1/training_data_balanced/training_data/38337.txt',
#  './1.0.1/training_data_balanced/training_data/38337_AV.hea',
#  './1.0.1/training_data_balanced/training_data/38337_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/38337_AV.wav',
#  './1.0.1/training_data_balanced/training_data/38337_MV.hea',
#  './1.0.1/training_data_balanced/training_data/38337_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/38337_MV.wav',
#  './1.0.1/training_data_balanced/training_data/39043.txt',
#  './1.0.1/training_data_balanced/training_data/39043_AV.hea',
#  './1.0.1/training_data_balanced/training_data/39043_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/39043_AV.wav',
#  './1.0.1/training_data_balanced/training_data/39043_MV.hea',
#  './1.0.1/training_data_balanced/training_data/39043_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/39043_MV.wav',
#  './1.0.1/training_data_balanced/training_data/39043_PV.hea',
#  './1.0.1/training_data_balanced/training_data/39043_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/39043_PV.wav',
#  './1.0.1/training_data_balanced/training_data/39043_TV.hea',
#  './1.0.1/training_data_balanced/training_data/39043_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/39043_TV.wav',
#  './1.0.1/training_data_balanced/training_data/39403.txt',
#  './1.0.1/training_data_balanced/training_data/39403_AV.hea',
#  './1.0.1/training_data_balanced/training_data/39403_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/39403_AV.wav',
#  './1.0.1/training_data_balanced/training_data/39403_MV.hea',
#  './1.0.1/training_data_balanced/training_data/39403_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/39403_MV.wav',
#  './1.0.1/training_data_balanced/training_data/39403_PV.hea',
#  './1.0.1/training_data_balanced/training_data/39403_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/39403_PV.wav',
#  './1.0.1/training_data_balanced/training_data/39403_TV.hea',
#  './1.0.1/training_data_balanced/training_data/39403_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/39403_TV.wav',
#  './1.0.1/training_data_balanced/training_data/39456.txt',
#  './1.0.1/training_data_balanced/training_data/39456_MV.hea',
#  './1.0.1/training_data_balanced/training_data/39456_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/39456_MV.wav',
#  './1.0.1/training_data_balanced/training_data/39456_PV.hea',
#  './1.0.1/training_data_balanced/training_data/39456_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/39456_PV.wav',
#  './1.0.1/training_data_balanced/training_data/39456_TV.hea',
#  './1.0.1/training_data_balanced/training_data/39456_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/39456_TV.wav',
#  './1.0.1/training_data_balanced/training_data/40058.txt',
#  './1.0.1/training_data_balanced/training_data/40058_AV.hea',
#  './1.0.1/training_data_balanced/training_data/40058_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/40058_AV.wav',
#  './1.0.1/training_data_balanced/training_data/40058_MV.hea',
#  './1.0.1/training_data_balanced/training_data/40058_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/40058_MV.wav',
#  './1.0.1/training_data_balanced/training_data/40058_PV.hea',
#  './1.0.1/training_data_balanced/training_data/40058_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/40058_PV.wav',
#  './1.0.1/training_data_balanced/training_data/40058_TV.hea',
#  './1.0.1/training_data_balanced/training_data/40058_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/40058_TV.wav',
#  './1.0.1/training_data_balanced/training_data/40798.txt',
#  './1.0.1/training_data_balanced/training_data/40798_AV.hea',
#  './1.0.1/training_data_balanced/training_data/40798_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/40798_AV.wav',
#  './1.0.1/training_data_balanced/training_data/40798_MV.hea',
#  './1.0.1/training_data_balanced/training_data/40798_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/40798_MV.wav',
#  './1.0.1/training_data_balanced/training_data/40798_PV.hea',
#  './1.0.1/training_data_balanced/training_data/40798_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/40798_PV.wav',
#  './1.0.1/training_data_balanced/training_data/40798_TV.hea',
#  './1.0.1/training_data_balanced/training_data/40798_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/40798_TV.wav',
#  './1.0.1/training_data_balanced/training_data/40840.txt',
#  './1.0.1/training_data_balanced/training_data/40840_AV.hea',
#  './1.0.1/training_data_balanced/training_data/40840_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/40840_AV.wav',
#  './1.0.1/training_data_balanced/training_data/40840_MV.hea',
#  './1.0.1/training_data_balanced/training_data/40840_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/40840_MV.wav',
#  './1.0.1/training_data_balanced/training_data/40840_PV.hea',
#  './1.0.1/training_data_balanced/training_data/40840_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/40840_PV.wav',
#  './1.0.1/training_data_balanced/training_data/40840_TV.hea',
#  './1.0.1/training_data_balanced/training_data/40840_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/40840_TV.wav',
#  './1.0.1/training_data_balanced/training_data/43852.txt',
#  './1.0.1/training_data_balanced/training_data/43852_AV.hea',
#  './1.0.1/training_data_balanced/training_data/43852_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/43852_AV.wav',
#  './1.0.1/training_data_balanced/training_data/43852_MV.hea',
#  './1.0.1/training_data_balanced/training_data/43852_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/43852_MV.wav',
#  './1.0.1/training_data_balanced/training_data/43852_PV.hea',
#  './1.0.1/training_data_balanced/training_data/43852_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/43852_PV.wav',
#  './1.0.1/training_data_balanced/training_data/43852_TV.hea',
#  './1.0.1/training_data_balanced/training_data/43852_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/43852_TV.wav',
#  './1.0.1/training_data_balanced/training_data/44514.txt',
#  './1.0.1/training_data_balanced/training_data/44514_AV.hea',
#  './1.0.1/training_data_balanced/training_data/44514_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/44514_AV.wav',
#  './1.0.1/training_data_balanced/training_data/44514_MV.hea',
#  './1.0.1/training_data_balanced/training_data/44514_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/44514_MV.wav',
#  './1.0.1/training_data_balanced/training_data/44514_PV.hea',
#  './1.0.1/training_data_balanced/training_data/44514_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/44514_PV.wav',
#  './1.0.1/training_data_balanced/training_data/44514_TV.hea',
#  './1.0.1/training_data_balanced/training_data/44514_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/44514_TV.wav',
#  './1.0.1/training_data_balanced/training_data/45843.txt',
#  './1.0.1/training_data_balanced/training_data/45843_AV.hea',
#  './1.0.1/training_data_balanced/training_data/45843_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/45843_AV.wav',
#  './1.0.1/training_data_balanced/training_data/45843_MV.hea',
#  './1.0.1/training_data_balanced/training_data/45843_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/45843_MV.wav',
#  './1.0.1/training_data_balanced/training_data/45843_PV.hea',
#  './1.0.1/training_data_balanced/training_data/45843_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/45843_PV.wav',
#  './1.0.1/training_data_balanced/training_data/45843_TV.hea',
#  './1.0.1/training_data_balanced/training_data/45843_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/45843_TV.wav',
#  './1.0.1/training_data_balanced/training_data/46065.txt',
#  './1.0.1/training_data_balanced/training_data/46065_AV.hea',
#  './1.0.1/training_data_balanced/training_data/46065_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/46065_AV.wav',
#  './1.0.1/training_data_balanced/training_data/46065_MV.hea',
#  './1.0.1/training_data_balanced/training_data/46065_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/46065_MV.wav',
#  './1.0.1/training_data_balanced/training_data/46065_PV.hea',
#  './1.0.1/training_data_balanced/training_data/46065_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/46065_PV.wav',
#  './1.0.1/training_data_balanced/training_data/46065_TV.hea',
#  './1.0.1/training_data_balanced/training_data/46065_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/46065_TV.wav',
#  './1.0.1/training_data_balanced/training_data/46532.txt',
#  './1.0.1/training_data_balanced/training_data/46532_AV.hea',
#  './1.0.1/training_data_balanced/training_data/46532_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/46532_AV.wav',
#  './1.0.1/training_data_balanced/training_data/46579.txt',
#  './1.0.1/training_data_balanced/training_data/46579_AV.hea',
#  './1.0.1/training_data_balanced/training_data/46579_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/46579_AV.wav',
#  './1.0.1/training_data_balanced/training_data/46579_MV.hea',
#  './1.0.1/training_data_balanced/training_data/46579_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/46579_MV.wav',
#  './1.0.1/training_data_balanced/training_data/46579_PV.hea',
#  './1.0.1/training_data_balanced/training_data/46579_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/46579_PV.wav',
#  './1.0.1/training_data_balanced/training_data/46579_TV.hea',
#  './1.0.1/training_data_balanced/training_data/46579_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/46579_TV.wav',
#  './1.0.1/training_data_balanced/training_data/46778.txt',
#  './1.0.1/training_data_balanced/training_data/46778_MV.hea',
#  './1.0.1/training_data_balanced/training_data/46778_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/46778_MV.wav',
#  './1.0.1/training_data_balanced/training_data/47002.txt',
#  './1.0.1/training_data_balanced/training_data/47002_AV.hea',
#  './1.0.1/training_data_balanced/training_data/47002_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/47002_AV.wav',
#  './1.0.1/training_data_balanced/training_data/47002_MV.hea',
#  './1.0.1/training_data_balanced/training_data/47002_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/47002_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49558.txt',
#  './1.0.1/training_data_balanced/training_data/49558_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49558_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49558_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49558_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49558_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49558_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49561.txt',
#  './1.0.1/training_data_balanced/training_data/49561_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49561_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49561_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49561_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49561_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49561_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49561_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49561_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49561_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49561_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49561_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49561_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49562.txt',
#  './1.0.1/training_data_balanced/training_data/49562_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49562_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49562_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49562_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49562_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49562_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49562_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49562_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49562_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49562_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49562_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49562_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49568.txt',
#  './1.0.1/training_data_balanced/training_data/49568_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49568_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49568_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49568_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49568_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49568_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49568_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49568_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49568_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49568_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49568_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49568_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49572.txt',
#  './1.0.1/training_data_balanced/training_data/49572_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49572_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49572_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49572_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49572_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49572_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49572_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49572_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49572_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49574.txt',
#  './1.0.1/training_data_balanced/training_data/49574_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49574_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49574_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49574_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49574_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49574_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49574_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49574_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49574_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49574_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49574_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49574_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49577.txt',
#  './1.0.1/training_data_balanced/training_data/49577_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49577_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49577_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49577_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49577_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49577_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49577_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49577_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49577_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49577_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49577_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49577_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49585.txt',
#  './1.0.1/training_data_balanced/training_data/49585_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49585_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49585_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49585_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49585_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49585_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49585_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49585_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49585_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49585_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49585_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49585_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49595.txt',
#  './1.0.1/training_data_balanced/training_data/49595_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49595_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49595_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49595_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49595_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49595_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49598.txt',
#  './1.0.1/training_data_balanced/training_data/49598_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49598_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49598_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49598_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49598_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49598_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49607.txt',
#  './1.0.1/training_data_balanced/training_data/49607_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49607_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49607_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49610.txt',
#  './1.0.1/training_data_balanced/training_data/49610_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49610_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49610_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49610_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49610_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49610_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49610_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49610_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49610_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49610_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49610_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49610_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49618.txt',
#  './1.0.1/training_data_balanced/training_data/49618_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49618_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49618_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49618_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49618_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49618_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49622.txt',
#  './1.0.1/training_data_balanced/training_data/49622_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49622_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49622_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49622_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49622_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49622_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49627.txt',
#  './1.0.1/training_data_balanced/training_data/49627_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49627_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49627_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49627_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49627_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49627_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49627_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49627_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49627_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49627_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49627_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49627_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49628.txt',
#  './1.0.1/training_data_balanced/training_data/49628_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49628_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49628_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49628_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49628_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49628_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49628_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49628_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49628_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49628_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49628_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49628_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49630.txt',
#  './1.0.1/training_data_balanced/training_data/49630_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49630_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49630_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49630_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49630_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49630_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49630_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49630_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49630_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49630_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49630_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49630_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49631.txt',
#  './1.0.1/training_data_balanced/training_data/49631_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49631_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49631_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49631_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49631_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49631_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49638.txt',
#  './1.0.1/training_data_balanced/training_data/49638_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49638_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49638_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49638_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49638_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49638_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49638_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49638_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49638_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49641.txt',
#  './1.0.1/training_data_balanced/training_data/49641_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49641_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49641_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49641_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49641_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49641_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49641_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49641_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49641_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49641_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49641_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49641_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49653.txt',
#  './1.0.1/training_data_balanced/training_data/49653_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49653_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49653_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49653_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49653_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49653_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49653_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49653_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49653_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49653_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49653_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49653_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49659.txt',
#  './1.0.1/training_data_balanced/training_data/49659_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49659_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49659_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49659_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49659_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49659_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49659_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49659_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49659_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49659_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49659_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49659_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49661.txt',
#  './1.0.1/training_data_balanced/training_data/49661_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49661_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49661_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49661_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49661_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49661_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49669.txt',
#  './1.0.1/training_data_balanced/training_data/49669_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49669_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49669_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49669_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49669_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49669_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49678.txt',
#  './1.0.1/training_data_balanced/training_data/49678_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49678_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49678_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49678_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49678_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49678_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49678_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49678_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49678_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49678_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49678_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49678_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49683.txt',
#  './1.0.1/training_data_balanced/training_data/49683_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49683_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49683_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49683_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49683_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49683_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49683_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49683_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49683_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49683_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49683_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49683_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49687.txt',
#  './1.0.1/training_data_balanced/training_data/49687_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49687_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49687_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49687_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49687_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49687_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49687_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49687_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49687_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49687_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49687_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49687_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49691.txt',
#  './1.0.1/training_data_balanced/training_data/49691_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49691_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49691_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49691_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49691_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49691_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49691_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49691_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49691_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49691_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49691_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49691_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49704.txt',
#  './1.0.1/training_data_balanced/training_data/49704_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49704_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49704_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49704_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49704_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49704_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49712.txt',
#  './1.0.1/training_data_balanced/training_data/49712_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49712_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49712_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49712_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49712_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49712_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49712_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49712_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49712_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49712_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49712_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49712_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49719.txt',
#  './1.0.1/training_data_balanced/training_data/49719_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49719_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49719_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49719_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49719_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49719_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49719_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49719_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49719_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49719_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49719_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49719_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49729.txt',
#  './1.0.1/training_data_balanced/training_data/49729_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49729_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49729_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49729_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49729_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49729_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49729_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49729_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49729_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49729_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49729_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49729_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49735.txt',
#  './1.0.1/training_data_balanced/training_data/49735_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49735_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49735_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49735_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49735_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49735_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49735_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49735_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49735_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49745.txt',
#  './1.0.1/training_data_balanced/training_data/49745_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49745_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49745_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49745_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49745_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49745_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49745_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49745_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49745_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49745_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49745_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49745_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49748.txt',
#  './1.0.1/training_data_balanced/training_data/49748_AV_1.hea',
#  './1.0.1/training_data_balanced/training_data/49748_AV_1.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_AV_1.wav',
#  './1.0.1/training_data_balanced/training_data/49748_AV_2.hea',
#  './1.0.1/training_data_balanced/training_data/49748_AV_2.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_AV_2.wav',
#  './1.0.1/training_data_balanced/training_data/49748_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49748_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49748_PV_1.hea',
#  './1.0.1/training_data_balanced/training_data/49748_PV_1.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_PV_1.wav',
#  './1.0.1/training_data_balanced/training_data/49748_PV_2.hea',
#  './1.0.1/training_data_balanced/training_data/49748_PV_2.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_PV_2.wav',
#  './1.0.1/training_data_balanced/training_data/49748_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49748_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49748_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49751.txt',
#  './1.0.1/training_data_balanced/training_data/49751_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49751_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49751_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49751_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49751_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49751_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49751_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49751_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49751_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49751_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49751_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49751_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49754.txt',
#  './1.0.1/training_data_balanced/training_data/49754_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49754_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49754_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49754_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49754_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49754_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49754_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49754_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49754_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49754_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49754_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49754_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49761.txt',
#  './1.0.1/training_data_balanced/training_data/49761_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49761_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49761_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49761_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49761_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49761_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49776.txt',
#  './1.0.1/training_data_balanced/training_data/49776_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49776_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49776_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49776_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49776_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49776_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49808.txt',
#  './1.0.1/training_data_balanced/training_data/49808_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49808_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49808_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49808_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49808_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49808_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49808_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49808_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49808_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49821.txt',
#  './1.0.1/training_data_balanced/training_data/49821_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49821_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49821_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49821_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49821_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49821_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49821_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49821_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49821_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49821_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49821_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49821_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49823.txt',
#  './1.0.1/training_data_balanced/training_data/49823_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49823_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49823_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49823_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49823_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49823_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49823_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49823_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49823_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49824.txt',
#  './1.0.1/training_data_balanced/training_data/49824_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49824_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49824_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49824_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49824_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49824_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49824_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49824_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49824_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49829.txt',
#  './1.0.1/training_data_balanced/training_data/49829_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49829_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49829_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49829_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49829_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49829_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49829_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49829_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49829_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49829_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49829_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49829_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49832.txt',
#  './1.0.1/training_data_balanced/training_data/49832_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49832_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49832_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49832_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49832_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49832_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49838.txt',
#  './1.0.1/training_data_balanced/training_data/49838_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49838_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49838_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49839.txt',
#  './1.0.1/training_data_balanced/training_data/49839_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49839_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49839_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49839_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49839_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49839_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49839_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49839_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49839_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49839_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49839_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49839_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49842.txt',
#  './1.0.1/training_data_balanced/training_data/49842_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49842_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49842_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49842_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49842_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49842_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49842_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49842_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49842_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49842_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49842_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49842_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49850.txt',
#  './1.0.1/training_data_balanced/training_data/49850_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49850_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49850_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49850_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49850_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49850_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49853.txt',
#  './1.0.1/training_data_balanced/training_data/49853_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49853_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49853_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49853_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49853_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49853_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49853_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49853_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49853_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49853_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49853_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49853_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49854.txt',
#  './1.0.1/training_data_balanced/training_data/49854_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49854_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49854_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49854_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49854_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49854_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49854_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49854_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49854_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49854_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49854_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49854_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49873.txt',
#  './1.0.1/training_data_balanced/training_data/49873_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49873_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49873_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49873_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49873_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49873_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49876.txt',
#  './1.0.1/training_data_balanced/training_data/49876_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49876_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49876_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49876_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49876_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49876_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49876_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49876_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49876_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49876_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49876_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49876_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49896.txt',
#  './1.0.1/training_data_balanced/training_data/49896_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49896_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49896_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49896_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49896_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49896_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49896_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49896_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49896_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49896_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49896_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49896_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49897.txt',
#  './1.0.1/training_data_balanced/training_data/49897_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49897_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49897_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49897_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49897_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49897_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49897_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49897_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49897_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49897_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49897_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49897_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49900.txt',
#  './1.0.1/training_data_balanced/training_data/49900_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49900_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49900_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49900_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49900_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49900_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49930.txt',
#  './1.0.1/training_data_balanced/training_data/49930_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49930_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49930_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49930_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49930_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49930_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49930_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49930_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49930_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49930_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49930_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49930_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49931.txt',
#  './1.0.1/training_data_balanced/training_data/49931_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49931_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49931_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49931_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49931_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49931_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49931_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49931_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49931_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49946.txt',
#  './1.0.1/training_data_balanced/training_data/49946_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49946_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49946_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49946_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49946_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49946_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49946_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49946_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49946_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49952.txt',
#  './1.0.1/training_data_balanced/training_data/49952_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49952_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49952_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49952_MV_1.hea',
#  './1.0.1/training_data_balanced/training_data/49952_MV_1.tsv',
#  './1.0.1/training_data_balanced/training_data/49952_MV_1.wav',
#  './1.0.1/training_data_balanced/training_data/49952_MV_2.hea',
#  './1.0.1/training_data_balanced/training_data/49952_MV_2.tsv',
#  './1.0.1/training_data_balanced/training_data/49952_MV_2.wav',
#  './1.0.1/training_data_balanced/training_data/49952_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49952_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49952_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49952_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49952_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49952_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49959.txt',
#  './1.0.1/training_data_balanced/training_data/49959_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49959_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49959_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49959_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49959_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49959_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49960.txt',
#  './1.0.1/training_data_balanced/training_data/49960_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49960_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49960_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49960_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49960_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49960_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49960_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49960_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49960_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49960_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49960_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49960_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49963.txt',
#  './1.0.1/training_data_balanced/training_data/49963_AV.hea',
#  './1.0.1/training_data_balanced/training_data/49963_AV.tsv',
#  './1.0.1/training_data_balanced/training_data/49963_AV.wav',
#  './1.0.1/training_data_balanced/training_data/49963_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49963_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49963_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49963_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49963_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49963_PV.wav',
#  './1.0.1/training_data_balanced/training_data/49963_TV.hea',
#  './1.0.1/training_data_balanced/training_data/49963_TV.tsv',
#  './1.0.1/training_data_balanced/training_data/49963_TV.wav',
#  './1.0.1/training_data_balanced/training_data/49966.txt',
#  './1.0.1/training_data_balanced/training_data/49966_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49966_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49966_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49968.txt',
#  './1.0.1/training_data_balanced/training_data/49968_MV.hea',
#  './1.0.1/training_data_balanced/training_data/49968_MV.tsv',
#  './1.0.1/training_data_balanced/training_data/49968_MV.wav',
#  './1.0.1/training_data_balanced/training_data/49968_PV.hea',
#  './1.0.1/training_data_balanced/training_data/49968_PV.tsv',
#  './1.0.1/training_data_balanced/training_data/49968_PV.wav',
#  ...]

# %%
# augments
augment = Compose([
    Reverse(p=0.8),
    PolarityInversion(p=1)
])

augment_spec = SpecCompose([
    SpecFrequencyMask(p=1)
])

def augment_signal(S,sr,outputpath):
    augmented_signal = augment(S,sr)
    sf.write(outputpath,augmented_signal,sr)


# for balancing
def grab_id(amt,val_srs):
    temp_idx=[]
    temp_count=0
    for i,k in val_srs.iteritems():
        if temp_count >= amt:
            break
        else:
            temp_count+=k
            temp_idx.append(i)
    return temp_idx

# feature extraction functions
def mfccs_features_extract(S,sr):
    mfccs_features = librosa.feature.mfcc(y=S, sr=sr, n_mfcc= 40)
    mfccs_features = librosa.decompose.nn_filter(mfccs_features)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis= 0)
    return mfccs_scaled_features,mfccs_features

# %%
# paths
data_path = "./1.0.1/"
augment_path = "./1.0.1/training_data_balanced/"
records = data_path+ "RECORDS"

# %%
demographics = pd.read_csv(data_path+"training_data.csv")
print("Class distribution by patient id")
demographics["Murmur"].value_counts(normalize=True)
# Out:
# Class distribution by patient id
# Absent     0.737792
# Present    0.190021
# Unknown    0.072187
# Name: Murmur, dtype: float64

# %%
# read all audio recordings and augment
with open(records,'r') as r:
    filenames = r.readlines()

    # dataframe containing audio recording path with corresponding patient_id
    file_df = pd.DataFrame(filenames,columns=["filenames"])
    file_df["filenames"] = file_df["filenames"].str.strip() + '.wav'
    file_df["patient_id"] = file_df["filenames"].str.split("/").str[1]
    file_df["patient_id"] = file_df["patient_id"].str.split("_").str[0].astype(str)
    # merge with demographics to enrich dataframe
    demographics["Patient ID"] = demographics["Patient ID"].astype(str)
    file_df = file_df.merge(
        demographics[["Murmur","Patient ID","Murmur locations"]],
        how='left',
        left_on='patient_id',
        right_on='Patient ID'
    )
    file_df.pop("Patient ID")
# class distribution by audio recordings
print("Class distribution by audio recordings"+ "\n" ,file_df["Murmur"].value_counts()) #Heavily biased to absent class

# grabbing only present and absent class
file_df_present = file_df.loc[file_df["Murmur"]=="Present"]
file_df_absent = file_df.loc[file_df["Murmur"]=="Absent"]

# creating test df
test_present_ids = grab_id(250,file_df_present["patient_id"].value_counts())
test_absent_ids = grab_id(250,file_df_absent["patient_id"].value_counts())
test_ids = test_absent_ids+test_present_ids
test_df = file_df.loc[file_df["patient_id"].isin(test_ids)]

# create train df
train_df = file_df.loc[~(file_df["patient_id"].isin(test_ids)) & (file_df["Murmur"] != "Unknown")]
print("\nTraining set class distribution (Pre-Augment)\n",train_df["Murmur"].value_counts())
print("\nAugmenting present class audio data\n")
print(train_df)
# augmenting present class audio data
filtered_train = train_df.loc[train_df["Murmur"]!="Absent"].copy()
for i,k in tqdm(filtered_train.iterrows(),total=filtered_train.shape[0]):
    list_of_murmur_locations = list(k["Murmur locations"].split("+"))
    ausc_location = k["filenames"].split("/")[1].split(".")[0].split("_")[1]
    if ausc_location.strip() in list_of_murmur_locations:
        S,sr = librosa.load(data_path+k["filenames"],sr=4000)
        augmented_signal = augment(S,sr)
        augmented_signal_filename = k["filenames"].split(".")[0]+"_a1.wav"
        augment_signal(S,sr,augment_path+augmented_signal_filename)
        train_df = train_df.append(pd.DataFrame(
            data=[[
                augmented_signal_filename,k["patient_id"],k["Murmur"],k["Murmur locations"]
                ]],
            columns=list(train_df.columns.values)
            ))
    else:
        train_df = train_df.drop(index=train_df.loc[train_df["filenames"]==k["filenames"]].index)
train_df.pop("Murmur locations")
print("\nTraining set class distribution (Post Signal Augment)\n",train_df["Murmur"].value_counts())
# Out:
# Class distribution by audio recordings
#  Absent     2391
# Present     616
# Unknown     156
# Name: Murmur, dtype: int64
#
# Training set class distribution (Pre-Augment)
#  Absent     2141
# Present     366
# Name: Murmur, dtype: int64
#
# Augmenting present class audio data
#
#                        filenames patient_id   Murmur Murmur locations
# 16    training_data/14241_AV.wav      14241  Present      AV+MV+PV+TV
# 17    training_data/14241_MV.wav      14241  Present      AV+MV+PV+TV
# 18    training_data/14241_PV.wav      14241  Present      AV+MV+PV+TV
# 19    training_data/14241_TV.wav      14241  Present      AV+MV+PV+TV
# 20    training_data/14998_AV.wav      14998   Absent              NaN
# ...                          ...        ...      ...              ...
# 3158  training_data/85345_AV.wav      85345   Absent              NaN
# 3159  training_data/85345_PV.wav      85345   Absent              NaN
# 3160  training_data/85349_AV.wav      85349   Absent              NaN
# 3161  training_data/85349_PV.wav      85349   Absent              NaN
# 3162  training_data/85349_TV.wav      85349   Absent              NaN
#
# [2507 rows x 4 columns]
# 100%|██████████| 366/366 [00:10<00:00, 35.42it/s]
# Training set class distribution (Post Signal Augment)
#  Absent     2141
# Present     598
# Name: Murmur, dtype: int64

# %%
train_df["data"] = np.array(None)
train_df = train_df.reset_index(drop=True)
# extracting features and augmenting mfcc spectogram for training set
print("\nExtracting features and augmenting present class mfcc spectogram\n")
for i,k in tqdm(train_df.copy().iterrows(),total=train_df.copy().shape[0]):
    S,sr = librosa.load(augment_path+k["filenames"],sr=4000)
    scaled_mfccs , mfccs = mfccs_features_extract(S,sr)
    train_df.loc[i,"data"] = scaled_mfccs
    if k["Murmur"] != "Absent":
        mfccs_augment = augment_spec(mfccs)
        mfccs_augment = np.mean(mfccs_augment.T,axis=0)
        train_df = train_df.append(pd.DataFrame(
            data=[[
                k["filenames"].replace(".wav","_augmentspect.wav"),
                k["patient_id"],
                k["Murmur"],
                mfccs_augment
            ]],
            columns=list(train_df.columns.values)
        ))
print("\nTraining set class distribution (Post Spectrogram augment))\n",train_df["Murmur"].value_counts())
# Out:
# Extracting features and augmenting present class mfcc spectogram
# 100%|██████████| 2739/2739 [05:19<00:00,  8.56it/s]
# Training set class distribution (Post Spectrogram augment))
#  Absent     2141
# Present    1196
# Name: Murmur, dtype: int64

# %%
# class balancing for training set
present_count = train_df["Murmur"].value_counts()[1]
print("Trim absent class data to match size of present class data and shuffle ")
absent_ids = grab_id(present_count,train_df.loc[train_df["Murmur"]=="Absent"]["patient_id"].value_counts())
train_df = pd.concat([
    train_df.loc[train_df["Murmur"]=="Present"],
    train_df.loc[(train_df["Murmur"]=="Absent")&(train_df["patient_id"].isin(absent_ids))]
]).sample(frac=1)
train_df = train_df.reset_index(drop=True)
print(train_df["Murmur"].value_counts())
# Out:
# Trim absent class data to match size of present class data and shuffle
# Present    1196
# Absent     1196
# Name: Murmur, dtype: int64

# %%
test_df["data"] = None
test_df = test_df.reset_index(drop=True)
for i,k in tqdm(test_df.copy().iterrows(),total=test_df.copy().shape[0]):
    S,sr = librosa.load(data_path+k["filenames"],sr=4000)
    test_scaled_mfccs, test_melspect = mfccs_features_extract(S,sr)
    test_df.loc[i,"data"] = test_scaled_mfccs
test_df = test_df.sample(frac=1).reset_index()
print("\nTesting set class distribution (final)\n",test_df["Murmur"].value_counts())
# Out:
# /tmp/ipykernel_539/529885081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["data"] = None
# 100%|██████████| 500/500 [00:49<00:00, 10.09it/s]
# Testing set class distribution (final)
#  Present    250
# Absent     250
# Name: Murmur, dtype: int64

# %%
# manual splitting and assigning data to variables
X_test = np.array(test_df["data"].tolist())
X_train = np.array(train_df["data"].tolist())
y_test = test_df["Murmur"]
y_train = train_df["Murmur"]


# export data 
import pickle 

pickle_out_X_train = open("./1.0.1/pickled_data/X_train_autosklearn_v2.pickle","wb")
pickle.dump(X_train,pickle_out_X_train)
pickle_out_X_train.close()

pickle_out_X_test = open("./1.0.1/pickled_data/X_test_autosklearn_v2.pickle","wb")
pickle.dump(X_test,pickle_out_X_test)
pickle_out_X_test.close()


pickle_out_y_train = open("./1.0.1/pickled_data/y_train_autosklearn_v2.pickle","wb")
pickle.dump(y_train,pickle_out_y_train)
pickle_out_y_train.close()

pickle_out_y_test = open("./1.0.1/pickled_data/y_test_autosklearn_v2.pickle","wb")
pickle.dump(y_test,pickle_out_y_test)
pickle_out_y_test.close()

# %%
X_test[0].shape
# Out:
# (40,)
